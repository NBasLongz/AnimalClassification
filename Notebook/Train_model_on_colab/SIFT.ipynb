# %% [markdown]
# # Khai báo Thư Viện

# %%
import os, sys, glob, random, shutil, json, time
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd



from sklearn.cluster import MiniBatchKMeans
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # Tải tập dữ liệu

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dimensi0n/afhq-512")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/dimensi0n/afhq-512?dataset_version_number=1...
# 100%|██████████| 6.48G/6.48G [00:59<00:00, 118MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/dimensi0n/afhq-512/versions/1

# %%
# Thư mục gốc chứa cat/dog/wild
base_dir = os.path.join(path)
print("Base dir (dataset gốc):", base_dir)

# Thư mục lưu sau khi chia train/val/test
output_dir = "/content/gdrive/MyDrive/afhq_split"
os.makedirs(output_dir, exist_ok=True)
# Out:
# Base dir (dataset gốc): /root/.cache/kagglehub/datasets/dimensi0n/afhq-512/versions/1

# %% [markdown]
# # EDA Dataset

# %%
classes = sorted([d for d in os.listdir(base_dir)
                 if os.path.isdir(os.path.join(base_dir, d))])
print(f"Các lớp: {classes}")
# Out:
# Các lớp: ['cat', 'dog', 'wild']

# %%
counts = []
for cname in classes:
    cpath = os.path.join(base_dir, cname)
    # Đếm số file ảnh
    num = len([f for f in os.listdir(cpath) if f.lower().endswith(('.jpg','.jpeg','.png'))])
    counts.append((cname, num))

counts_df = pd.DataFrame(counts, columns=["Class","Count"])
display(counts_df)
# Out:
#   Class  Count
# 0   cat   5558
# 1   dog   5169
# 2  wild   5076

# %%
counts_df = pd.DataFrame(counts, columns=["Class", "Count"])
plt.figure(figsize=(8, 4))
sns.barplot(data=counts_df, y="Class", x="Count", hue="Class", legend=False, palette="viridis")
plt.title("Phân bố dữ liệu Dataset")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Hiển thị mỗi lớp một ảnh

# %%
from PIL import Image

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for i, cls in enumerate(classes):
    cls_path = os.path.join(base_dir, cls)
    imgs = [f for f in os.listdir(cls_path) if f.lower().endswith(('.jpg', '.png'))]
    if imgs:
        img = Image.open(os.path.join(cls_path, imgs[0])).convert('RGB')
        axes[i].imshow(img)
        axes[i].set_title(cls, fontsize=14, fontweight='bold')
        axes[i].axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Chia tập dữ liệu

# %%
TRAIN_DIR = f"{output_dir}/train"
TEST_DIR = f"{output_dir}/test"

# %%
if os.path.exists(TRAIN_DIR) and os.path.exists(TEST_DIR):
    print("Dataset đã được chia trước đó. Skip.")
else:
    print("Đang chia dataset...")
    for cls in classes:
        cls_path = os.path.join(base_dir, cls)
        files = [os.path.join(cls_path, f) for f in os.listdir(cls_path)
                if f.lower().endswith(('.jpg', '.png', '.jpeg'))]

        train_files, test_files = train_test_split(files, test_size=0.2,
                                                   random_state=42)

        # Copy vào thư mục train
        train_cls_dir = os.path.join(TRAIN_DIR, cls)
        os.makedirs(train_cls_dir, exist_ok=True)
        for f in train_files:
            shutil.copy(f, train_cls_dir)

        # Copy vào thư mục test
        test_cls_dir = os.path.join(TEST_DIR, cls)
        os.makedirs(test_cls_dir, exist_ok=True)
        for f in test_files:
            shutil.copy(f, test_cls_dir)

        print(f"  {cls}: Train={len(train_files)}, Test={len(test_files)}")
# Out:
# Đang chia dataset...
#   cat: Train=4446, Test=1112
#   dog: Train=4135, Test=1034
#   wild: Train=4060, Test=1016

# %% [markdown]
# # Minh họa mẫu

# %%
sample_cls = classes[0]
sample_dir = os.path.join(TRAIN_DIR, sample_cls)
sample_imgs = [f for f in os.listdir(sample_dir) if f.endswith(('.jpg', '.png'))]
sample_img_path = os.path.join(sample_dir, sample_imgs[0])

print(f"Ảnh mẫu: {sample_img_path}")
plt.figure(figsize=(5, 5))
plt.imshow(plt.imread(sample_img_path))
plt.axis('off')
plt.show()
# Out:
# Ảnh mẫu: /content/gdrive/MyDrive/afhq_split/train/cat/5352.png

# %%
sift = cv2.SIFT_create(nfeatures=700)
img = cv2.imread(sample_img_path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
keypoints, desc = sift.detectAndCompute(gray, None)
print(f"Số keypoints: {len(keypoints)}")
plt.figure(figsize=(10, 10))
img_keypoints = cv2.drawKeypoints(img, keypoints, None, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
img_keypoints_rgb = cv2.cvtColor(img_keypoints, cv2.COLOR_BGR2RGB)
plt.imshow(img_keypoints_rgb)
plt.axis('off')
plt.show()
# Out:
# Số keypoints: 330

# %% [markdown]
# # Trích xuất đặc trưng

# %%
def load_image_paths_and_labels(root_dir):
    """
    root_dir: thư mục train/ hoặc val/ hoặc test/
    return:
        - image_paths: list[str]
        - labels: list[str]
    """
    image_paths = []
    labels = []

    classes = sorted(os.listdir(root_dir))  # ['cat', 'dog', 'wild', ...]
    for cls in classes:
        cls_dir = os.path.join(root_dir, cls)
        if not os.path.isdir(cls_dir):
            continue
        for fname in os.listdir(cls_dir):
            fpath = os.path.join(cls_dir, fname)
            if fpath.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp')):
                image_paths.append(fpath)
                labels.append(cls)

    return image_paths, labels

# %%
def extract_sift_descriptors(image_paths, max_keypoints=700):
    """
    Trích descriptor SIFT cho từng ảnh.
    Trả về:
        - descriptors_per_image: list[np.ndarray or None]
        - all_descriptors: np.ndarray (gộp tất cả để train KMeans)
    """
    sift = cv2.SIFT_create(nfeatures=max_keypoints)
    descriptors_per_image = []
    all_desc_list = []

    for path in image_paths:
        img = cv2.imread(path)
        if img is None:
            descriptors_per_image.append(None)
            continue

        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        keypoints, desc = sift.detectAndCompute(gray, None)

        if desc is None:
            descriptors_per_image.append(None)
            continue

        # L2 normalize từng descriptor (optional nhưng tốt)
        norms = np.linalg.norm(desc, axis=1, keepdims=True) + 1e-7
        desc_norm = desc / norms

        descriptors_per_image.append(desc_norm)
        all_desc_list.append(desc_norm)

    if len(all_desc_list) == 0:
        raise ValueError("Không trích được descriptor nào, kiểm tra lại ảnh/dataset.")

    all_descriptors = np.vstack(all_desc_list)
    return descriptors_per_image, all_descriptors

# %%
from sklearn.cluster import MiniBatchKMeans

def build_codebook(all_descriptors, n_clusters=200, batch_size=1000):
    """
    Train MiniBatchKMeans trên toàn bộ descriptor.
    """
    kmeans = MiniBatchKMeans(
        n_clusters=n_clusters,
        batch_size=batch_size,
        random_state=42,
        verbose=1
    )
    kmeans.fit(all_descriptors)
    return kmeans

# %%
def build_bovw_features(descriptors_per_image, kmeans, n_clusters):
    """
    Với mỗi ảnh:
        - gán mỗi descriptor vào 1 cluster
        - đếm histogram (length = n_clusters)
        - L2 normalize histogram
    """
    n_images = len(descriptors_per_image)
    X = np.zeros((n_images, n_clusters), dtype=np.float32)

    for i, desc in enumerate(descriptors_per_image):
        if desc is None:
            # Ảnh không có keypoint → histogram toàn 0
            continue

        # Dự đoán cluster cho từng descriptor
        cluster_idx = kmeans.predict(desc)
        hist, _ = np.histogram(cluster_idx, bins=np.arange(n_clusters+1))
        hist = hist.astype(np.float32)

        # L2 normalize histogram
        norm = np.linalg.norm(hist) + 1e-7
        hist /= norm

        X[i, :] = hist

    return X

# %%
TRAIN_DIR = os.path.join(output_dir, "train")
TEST_DIR  = os.path.join(output_dir, "test")

# 1) Load path + label
train_paths, y_train = load_image_paths_and_labels(TRAIN_DIR)
test_paths,  y_test  = load_image_paths_and_labels(TEST_DIR)

print("Số ảnh train:", len(train_paths))
print("Số ảnh test:", len(test_paths))

# 2) Trích SIFT cho train, val, test
train_desc_per_img, train_all_desc = extract_sift_descriptors(train_paths, max_keypoints=700)
test_desc_per_img,  _              = extract_sift_descriptors(test_paths,  max_keypoints=700)

print("Tổng descriptor train:", train_all_desc.shape)

# 3) Train codebook trên descriptor train
N_CLUSTERS = 300
kmeans = build_codebook(train_all_desc, n_clusters=N_CLUSTERS, batch_size=2000)

# 4) Convert sang BoVW feature
X_train = build_bovw_features(train_desc_per_img, kmeans, N_CLUSTERS)
X_test  = build_bovw_features(test_desc_per_img,  kmeans, N_CLUSTERS)

y_train = np.array(y_train)
y_test  = np.array(y_test)

print("X_train shape:", X_train.shape)
print("X_test shape:",  X_test.shape)
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# Minibatch step 2126/400770: mean batch inertia: 0.27183746337890624, ewa inertia: 0.2827340865687529
# Minibatch step 2127/400770: mean batch inertia: 0.27193170166015623, ewa inertia: 0.28272869575967075
# Minibatch step 2128/400770: mean batch inertia: 0.2690849609375, ewa inertia: 0.28272188700676887
# Minibatch step 2129/400770: mean batch inertia: 0.26622802734375, ewa inertia: 0.28271365593101816
# Minibatch step 2130/400770: mean batch inertia: 0.2719686889648438, ewa inertia: 0.28270829377571643
# Minibatch step 2131/400770: mean batch inertia: 0.26993426513671875, ewa inertia: 0.2827019190399349
# Minibatch step 2132/400770: mean batch inertia: 0.2696377258300781, ewa inertia: 0.2826953995007774
# Minibatch step 2133/400770: mean batch inertia: 0.2737480773925781, ewa inertia: 0.2826909344399885
# Minibatch step 2134/400770: mean batch inertia: 0.26842449951171876, ewa inertia: 0.2826838149355798
# Minibatch step 2135/400770: mean batch inertia: 0.27059490966796873, ewa inertia: 0.2826777821029358
# Minibatch step 2136/400770: mean batch inertia: 0.269327880859375, ewa inertia: 0.2826711199843871
# Minibatch step 2137/400770: mean batch inertia: 0.2703332214355469, ewa inertia: 0.2826649628944376
# Minibatch step 2138/400770: mean batch inertia: 0.2689461975097656, ewa inertia: 0.28265811669837465
# Minibatch step 2139/400770: mean batch inertia: 0.2717562561035156, ewa inertia: 0.2826526762470665
# Minibatch step 2140/400770: mean batch inertia: 0.26943704223632814, ewa inertia: 0.2826460811330751
# Minibatch step 2141/400770: mean batch inertia: 0.27112014770507814, ewa inertia: 0.2826403292452161
# Minibatch step 2142/400770: mean batch inertia: 0.2679605712890625, ewa inertia: 0.2826330034765841
# Minibatch step 2143/400770: mean batch inertia: 0.2680506591796875, ewa inertia: 0.2826257263211467
# Minibatch step 2144/400770: mean batch inertia: 0.2702012939453125, ewa inertia: 0.28261952604746093
# Minibatch step 2145/400770: mean batch inertia: 0.2693150939941406, ewa inertia: 0.2826128866198019
# Minibatch step 2146/400770: mean batch inertia: 0.271547119140625, ewa inertia: 0.2826073643726007
# Minibatch step 2147/400770: mean batch inertia: 0.2727687072753906, ewa inertia: 0.2826024545010784
# Minibatch step 2148/400770: mean batch inertia: 0.2712904052734375, ewa inertia: 0.28259680934973175
# Minibatch step 2149/400770: mean batch inertia: 0.2687981567382812, ewa inertia: 0.2825899232868439
# Minibatch step 2150/400770: mean batch inertia: 0.2691089782714844, ewa inertia: 0.28258319577237007
# Minibatch step 2151/400770: mean batch inertia: 0.26989849853515624, ewa inertia: 0.2825768656164231
# Minibatch step 2152/400770: mean batch inertia: 0.2687337646484375, ewa inertia: 0.28256995737208124
# Minibatch step 2153/400770: mean batch inertia: 0.2706919250488281, ewa inertia: 0.282564029773216
# Minibatch step 2154/400770: mean batch inertia: 0.2710185852050781, ewa inertia: 0.2825582681485413
# Minibatch step 2155/400770: mean batch inertia: 0.2708203430175781, ewa inertia: 0.2825524104685996
# Minibatch step 2156/400770: mean batch inertia: 0.27011904907226564, ewa inertia: 0.28254620573898626
# Minibatch step 2157/400770: mean batch inertia: 0.26915798950195313, ewa inertia: 0.28253952449976966
# Minibatch step 2158/400770: mean batch inertia: 0.27283984375, ewa inertia: 0.2825346839828355
# Minibatch step 2159/400770: mean batch inertia: 0.2721214294433594, ewa inertia: 0.2825294873649015
# Minibatch step 2160/400770: mean batch inertia: 0.27234201049804685, ewa inertia: 0.2825244034187838
# Minibatch step 2161/400770: mean batch inertia: 0.26708944702148435, ewa inertia: 0.2825167007768364
# Minibatch step 2162/400770: mean batch inertia: 0.27267922973632813, ewa inertia: 0.2825117914972024
# Minibatch step 2163/400770: mean batch inertia: 0.27092852783203125, ewa inertia: 0.28250601099933126
# Minibatch step 2164/400770: mean batch inertia: 0.272352294921875, ewa inertia: 0.282500943901157
# Minibatch step 2165/400770: mean batch inertia: 0.2718255615234375, ewa inertia: 0.28249561647126403
# Minibatch step 2166/400770: mean batch inertia: 0.2716508483886719, ewa inertia: 0.28249020451133405
# Minibatch step 2167/400770: mean batch inertia: 0.2663501892089844, ewa inertia: 0.28248215001764454
# Minibatch step 2168/400770: mean batch inertia: 0.27106048583984377, ewa inertia: 0.28247645016418593
# Minibatch step 2169/400770: mean batch inertia: 0.2692604064941406, ewa inertia: 0.28246985484575865
# Minibatch step 2170/400770: mean batch inertia: 0.2706666564941406, ewa inertia: 0.282463964591948
# Minibatch step 2171/400770: mean batch inertia: 0.2698921508789062, ewa inertia: 0.2824576907692582
# Minibatch step 2172/400770: mean batch inertia: 0.27342279052734375, ewa inertia: 0.28245318200358355
# Minibatch step 2173/400770: mean batch inertia: 0.27505380249023437, ewa inertia: 0.2824494894261925
# Minibatch step 2174/400770: mean batch inertia: 0.27127468872070315, ewa inertia: 0.28244391276718217
# Minibatch step 2175/400770: mean batch inertia: 0.2722074279785156, ewa inertia: 0.28243880436421054
# Minibatch step 2176/400770: mean batch inertia: 0.26741156005859373, ewa inertia: 0.2824313051864116
# Minibatch step 2177/400770: mean batch inertia: 0.26903878784179686, ewa inertia: 0.28242462180077543
# Minibatch step 2178/400770: mean batch inertia: 0.2702054138183594, ewa inertia: 0.28241852394202244
# Minibatch step 2179/400770: mean batch inertia: 0.27055490112304686, ewa inertia: 0.2824126035340587
# Minibatch step 2180/400770: mean batch inertia: 0.2714634704589844, ewa inertia: 0.2824071394919493
# Minibatch step 2181/400770: mean batch inertia: 0.27207177734375, ewa inertia: 0.2824019817453399
# Minibatch step 2182/400770: mean batch inertia: 0.2707176513671875, ewa inertia: 0.28239615081125874
# Minibatch step 2183/400770: mean batch inertia: 0.2702089538574219, ewa inertia: 0.28239006892725066
# Minibatch step 2184/400770: mean batch inertia: 0.27209365844726563, ewa inertia: 0.2823849306190346
# Minibatch step 2185/400770: mean batch inertia: 0.27437261962890624, ewa inertia: 0.28238093216506166
# Minibatch step 2186/400770: mean batch inertia: 0.2719087524414063, ewa inertia: 0.2823757061411751
# Minibatch step 2187/400770: mean batch inertia: 0.27097723388671874, ewa inertia: 0.28237001786138577
# Minibatch step 2188/400770: mean batch inertia: 0.2708595275878906, ewa inertia: 0.2823642736802599
# Minibatch step 2189/400770: mean batch inertia: 0.2680911865234375, ewa inertia: 0.28235715085613117
# Minibatch step 2190/400770: mean batch inertia: 0.26735812377929685, ewa inertia: 0.2823496657598239
# Minibatch step 2191/400770: mean batch inertia: 0.273787353515625, ewa inertia: 0.28234539283389126
# Minibatch step 2192/400770: mean batch inertia: 0.2712500915527344, ewa inertia: 0.2823398558481773
# Minibatch step 2193/400770: mean batch inertia: 0.272212890625, ewa inertia: 0.28233480209971695
# Minibatch step 2194/400770: mean batch inertia: 0.26771438598632813, ewa inertia: 0.28232750594496636
# Minibatch step 2195/400770: mean batch inertia: 0.2715758361816406, ewa inertia: 0.2823221404447089
# Minibatch step 2196/400770: mean batch inertia: 0.2690645446777344, ewa inertia: 0.2823155243901735
# Minibatch step 2197/400770: mean batch inertia: 0.2741005554199219, ewa inertia: 0.28231142480200766
# Minibatch step 2198/400770: mean batch inertia: 0.2686573486328125, ewa inertia: 0.28230461088837244
# Minibatch step 2199/400770: mean batch inertia: 0.2731185302734375, ewa inertia: 0.28230002667782755
# Minibatch step 2200/400770: mean batch inertia: 0.26950540161132813, ewa inertia: 0.2822936416636298
# Minibatch step 2201/400770: mean batch inertia: 0.2721361083984375, ewa inertia: 0.2822885726605308
# Minibatch step 2202/400770: mean batch inertia: 0.2705975036621094, ewa inertia: 0.2822827383636168
# Minibatch step 2203/400770: mean batch inertia: 0.26682659912109374, ewa inertia: 0.28227502515060793
# Minibatch step 2204/400770: mean batch inertia: 0.271530029296875, ewa inertia: 0.28226966298089023
# Minibatch step 2205/400770: mean batch inertia: 0.26850466918945315, ewa inertia: 0.2822627937150592
# Minibatch step 2206/400770: mean batch inertia: 0.2718291931152344, ewa inertia: 0.2822575869436519
# Minibatch step 2207/400770: mean batch inertia: 0.2698780822753906, ewa inertia: 0.2822514090906349
# Minibatch step 2208/400770: mean batch inertia: 0.271645751953125, ewa inertia: 0.2822461164563414
# Minibatch step 2209/400770: mean batch inertia: 0.2705745849609375, ewa inertia: 0.2822402919093992
# Minibatch step 2210/400770: mean batch inertia: 0.2711861877441406, ewa inertia: 0.28223477548264403
# Minibatch step 2211/400770: mean batch inertia: 0.272998291015625, ewa inertia: 0.28223016611862184
# Minibatch step 2212/400770: mean batch inertia: 0.2705836791992188, ewa inertia: 0.28222435406989455
# Minibatch step 2213/400770: mean batch inertia: 0.270537109375, ewa inertia: 0.2822185216814563
# Minibatch step 2214/400770: mean batch inertia: 0.26984683227539064, ewa inertia: 0.2822123477285583
# Minibatch step 2215/400770: mean batch inertia: 0.27098147583007814, ewa inertia: 0.28220674308784766
# Minibatch step 2216/400770: mean batch inertia: 0.271932373046875, ewa inertia: 0.28220161577866554
# Minibatch step 2217/400770: mean batch inertia: 0.267774658203125, ewa inertia: 0.28219441616722934
# Minibatch step 2218/400770: mean batch inertia: 0.26894015502929686, ewa inertia: 0.28218780177680314
# Minibatch step 2219/400770: mean batch inertia: 0.27382611083984376, ewa inertia: 0.2821836289686847
# Minibatch step 2220/400770: mean batch inertia: 0.2662069091796875, ewa inertia: 0.2821756559657904
# Minibatch step 2221/400770: mean batch inertia: 0.2691797180175781, ewa inertia: 0.282169170488656
# Minibatch step 2222/400770: mean batch inertia: 0.27097244262695314, ewa inertia: 0.2821635828871441
# Minibatch step 2223/400770: mean batch inertia: 0.2703287353515625, ewa inertia: 0.282157676839163
# Minibatch step 2224/400770: mean batch inertia: 0.26965438842773437, ewa inertia: 0.2821514372132567
# Minibatch step 2225/400770: mean batch inertia: 0.2714159240722656, ewa inertia: 0.2821460797757805
# Minibatch step 2226/400770: mean batch inertia: 0.2719198913574219, ewa inertia: 0.28214097651109704
# Minibatch step 2227/400770: mean batch inertia: 0.267860595703125, ewa inertia: 0.2821338500471534
# Minibatch step 2228/400770: mean batch inertia: 0.2685882263183594, ewa inertia: 0.28212709025549276
# Minibatch step 2229/400770: mean batch inertia: 0.269133056640625, ewa inertia: 0.2821206057286945
# Minibatch step 2230/400770: mean batch inertia: 0.27297869873046876, ewa inertia: 0.28211604356249775
# Minibatch step 2231/400770: mean batch inertia: 0.2736104125976562, ewa inertia: 0.28211179892272215
# Minibatch step 2232/400770: mean batch inertia: 0.27095001220703124, ewa inertia: 0.28210622875819746
# Minibatch step 2233/400770: mean batch inertia: 0.27096697998046876, ewa inertia: 0.2821006698409781
# Minibatch step 2234/400770: mean batch inertia: 0.27054217529296876, ewa inertia: 0.2820949017038572
# Minibatch step 2235/400770: mean batch inertia: 0.2686619262695312, ewa inertia: 0.282088198128065
# Minibatch step 2236/400770: mean batch inertia: 0.27161636352539065, ewa inertia: 0.2820829722764072
# Minibatch step 2237/400770: mean batch inertia: 0.26886090087890624, ewa inertia: 0.2820763739499101
# Minibatch step 2238/400770: mean batch inertia: 0.2696268615722656, ewa inertia: 0.28207016116033057
# Minibatch step 2239/400770: mean batch inertia: 0.26505450439453127, ewa inertia: 0.2820616696875856
# Minibatch step 2240/400770: mean batch inertia: 0.2714275512695313, ewa inertia: 0.2820563628500091
# Minibatch step 2241/400770: mean batch inertia: 0.2702132568359375, ewa inertia: 0.2820504526807269
# Minibatch step 2242/400770: mean batch inertia: 0.2714486999511719, ewa inertia: 0.28204516199488444
# Minibatch step 2243/400770: mean batch inertia: 0.2673871154785156, ewa inertia: 0.2820378470611031
# Minibatch step 2244/400770: mean batch inertia: 0.27201318359375, ewa inertia: 0.2820328443651871
# Minibatch step 2245/400770: mean batch inertia: 0.2719624633789062, ewa inertia: 0.2820278188544558
# Minibatch step 2246/400770: mean batch inertia: 0.2714320983886719, ewa inertia: 0.28202253117894693
# Minibatch step 2247/400770: mean batch inertia: 0.2727764892578125, ewa inertia: 0.28201791704538437
# Minibatch step 2248/400770: mean batch inertia: 0.26891275024414063, ewa inertia: 0.2820113770588154
# Minibatch step 2249/400770: mean batch inertia: 0.27226123046875, ewa inertia: 0.2820065113574694
# Minibatch step 2250/400770: mean batch inertia: 0.2675484313964844, ewa inertia: 0.28199929621475567
# Minibatch step 2251/400770: mean batch inertia: 0.2698101196289063, ewa inertia: 0.28199321334283445
# Minibatch step 2252/400770: mean batch inertia: 0.2727649230957031, ewa inertia: 0.28198860806804577
# Minibatch step 2253/400770: mean batch inertia: 0.27135113525390625, ewa inertia: 0.28198329955649554
# Minibatch step 2254/400770: mean batch inertia: 0.2680178527832031, ewa inertia: 0.2819763302568512
# Minibatch step 2255/400770: mean batch inertia: 0.26864224243164064, ewa inertia: 0.28196967602981166
# Minibatch step 2256/400770: mean batch inertia: 0.268917236328125, ewa inertia: 0.2819631623561106
# Minibatch step 2257/400770: mean batch inertia: 0.27067654418945314, ewa inertia: 0.2819575298958498
# Minibatch step 2258/400770: mean batch inertia: 0.2667111511230469, ewa inertia: 0.28194992136145175
# Minibatch step 2259/400770: mean batch inertia: 0.27513934326171874, ewa inertia: 0.28194652261880504
# Minibatch step 2260/400770: mean batch inertia: 0.27265167236328125, ewa inertia: 0.28194188412799037
# Minibatch step 2261/400770: mean batch inertia: 0.2712932434082031, ewa inertia: 0.28193657004322203
# Minibatch step 2262/400770: mean batch inertia: 0.27009561157226564, ewa inertia: 0.2819306609456471
# Minibatch step 2263/400770: mean batch inertia: 0.2679687805175781, ewa inertia: 0.28192369342574736
# Minibatch step 2264/400770: mean batch inertia: 0.2680547790527344, ewa inertia: 0.2819167722995151
# Minibatch step 2265/400770: mean batch inertia: 0.2710139465332031, ewa inertia: 0.28191133136654895
# Minibatch step 2266/400770: mean batch inertia: 0.27025830078125, ewa inertia: 0.2819055160522785
# Minibatch step 2267/400770: mean batch inertia: 0.2711484069824219, ewa inertia: 0.2819001478375961
# Minibatch step 2268/400770: mean batch inertia: 0.2684267272949219, ewa inertia: 0.28189342407812595
# Minibatch step 2269/400770: mean batch inertia: 0.2745631103515625, ewa inertia: 0.2818897659672415
# Minibatch step 2270/400770: mean batch inertia: 0.2689040222167969, ewa inertia: 0.28188328557740716
# Minibatch step 2271/400770: mean batch inertia: 0.2704057312011719, ewa inertia: 0.2818775578325716
# Minibatch step 2272/400770: mean batch inertia: 0.2687608642578125, ewa inertia: 0.2818710120936955
# Minibatch step 2273/400770: mean batch inertia: 0.269420654296875, ewa inertia: 0.2818647988822191
# Minibatch step 2274/400770: mean batch inertia: 0.27223052978515627, ewa inertia: 0.2818599910082369
# Minibatch step 2275/400770: mean batch inertia: 0.2709497375488281, ewa inertia: 0.2818545463685638
# Minibatch step 2276/400770: mean batch inertia: 0.271639404296875, ewa inertia: 0.28184944861643574
# Minibatch step 2277/400770: mean batch inertia: 0.2726094970703125, ewa inertia: 0.28184483752220657
# Minibatch step 2278/400770: mean batch inertia: 0.27015869140625, ewa inertia: 0.2818390056820018
# Minibatch step 2279/400770: mean batch inertia: 0.2707505798339844, ewa inertia: 0.2818334721273957
# Minibatch step 2280/400770: mean batch inertia: 0.2710733947753906, ewa inertia: 0.28182810243142536
# Minibatch step 2281/400770: mean batch inertia: 0.2716658935546875, ewa inertia: 0.2818230310950149
# Minibatch step 2282/400770: mean batch inertia: 0.26975933837890625, ewa inertia: 0.2818170108444121
# Minibatch step 2283/400770: mean batch inertia: 0.27120199584960936, ewa inertia: 0.2818117135401848
# Minibatch step 2284/400770: mean batch inertia: 0.2730083312988281, ewa inertia: 0.2818073203109727
# Minibatch step 2285/400770: mean batch inertia: 0.2744380798339844, ewa inertia: 0.2818036427741299
# Minibatch step 2286/400770: mean batch inertia: 0.26973208618164063, ewa inertia: 0.2817976185991477
# Minibatch step 2287/400770: mean batch inertia: 0.27088113403320313, ewa inertia: 0.28179217084991076
# Minibatch step 2288/400770: mean batch inertia: 0.27125750732421877, ewa inertia: 0.2817869136441833
# Minibatch step 2289/400770: mean batch inertia: 0.2695547790527344, ewa inertia: 0.28178080933455096
# Minibatch step 2290/400770: mean batch inertia: 0.2679798278808594, ewa inertia: 0.2817739221094805
# Minibatch step 2291/400770: mean batch inertia: 0.27057882690429685, ewa inertia: 0.28176833532272755
# Minibatch step 2292/400770: mean batch inertia: 0.2696718444824219, ewa inertia: 0.2817622987045885
# Minibatch step 2293/400770: mean batch inertia: 0.26924609375, ewa inertia: 0.2817560526328262
# Minibatch step 2294/400770: mean batch inertia: 0.2718626403808594, ewa inertia: 0.2817511154363578
# Minibatch step 2295/400770: mean batch inertia: 0.27206930541992186, ewa inertia: 0.2817462838376127
# Minibatch step 2296/400770: mean batch inertia: 0.2688741149902344, ewa inertia: 0.2817398601260604
# Minibatch step 2297/400770: mean batch inertia: 0.26952056884765624, ewa inertia: 0.2817337622257395
# Minibatch step 2298/400770: mean batch inertia: 0.268986572265625, ewa inertia: 0.2817274008834998
# Minibatch step 2299/400770: mean batch inertia: 0.2677626953125, ewa inertia: 0.28172043195374413
# Minibatch step 2300/400770: mean batch inertia: 0.2700479736328125, ewa inertia: 0.2817146069442801
# Minibatch step 2301/400770: mean batch inertia: 0.2692701416015625, ewa inertia: 0.2817083966733668
# Minibatch step 2302/400770: mean batch inertia: 0.2687445373535156, ewa inertia: 0.2817019272047122
# Minibatch step 2303/400770: mean batch inertia: 0.2732149353027344, ewa inertia: 0.28169769186655197
# Minibatch step 2304/400770: mean batch inertia: 0.26907852172851565, ewa inertia: 0.2816913944111692
# Minibatch step 2305/400770: mean batch inertia: 0.271566650390625, ewa inertia: 0.28168634177117513
# Minibatch step 2306/400770: mean batch inertia: 0.2712659606933594, ewa inertia: 0.28168114159682206
# Minibatch step 2307/400770: mean batch inertia: 0.26682171630859375, ewa inertia: 0.2816737261672223
# Minibatch step 2308/400770: mean batch inertia: 0.2724135437011719, ewa inertia: 0.2816691049769794
# Minibatch step 2309/400770: mean batch inertia: 0.268728759765625, ewa inertia: 0.281662647242777
# Minibatch step 2310/400770: mean batch inertia: 0.27035595703125, ewa inertia: 0.28165700476578726
# Minibatch step 2311/400770: mean batch inertia: 0.27280517578125, ewa inertia: 0.2816525873597711
# Minibatch step 2312/400770: mean batch inertia: 0.27032717895507813, ewa inertia: 0.28164693554167686
# Minibatch step 2313/400770: mean batch inertia: 0.26591494750976563, ewa inertia: 0.2816390846694222
# Minibatch step 2314/400770: mean batch inertia: 0.27123739624023435, ewa inertia: 0.28163389382342585
# Minibatch step 2315/400770: mean batch inertia: 0.27025967407226564, ewa inertia: 0.2816282176465764
# Minibatch step 2316/400770: mean batch inertia: 0.2722266845703125, ewa inertia: 0.28162352591689616
# Minibatch step 2317/400770: mean batch inertia: 0.26976962280273437, ewa inertia: 0.2816176103594422
# Minibatch step 2318/400770: mean batch inertia: 0.26945870971679686, ewa inertia: 0.28161154259639104
# Minibatch step 2319/400770: mean batch inertia: 0.26941436767578125, ewa inertia: 0.2816054557329905
# Minibatch step 2320/400770: mean batch inertia: 0.27024905395507814, ewa inertia: 0.2815997884480009
# Minibatch step 2321/400770: mean batch inertia: 0.2719531860351562, ewa inertia: 0.28159497441921566
# Minibatch step 2322/400770: mean batch inertia: 0.26621282958984377, ewa inertia: 0.28158729813228917
# Minibatch step 2323/400770: mean batch inertia: 0.2701422729492188, ewa inertia: 0.28158158662078275
# Minibatch step 2324/400770: mean batch inertia: 0.27093115234375, ewa inertia: 0.2815762716409598
# Minibatch step 2325/400770: mean batch inertia: 0.271166015625, ewa inertia: 0.28157107651940533
# Minibatch step 2326/400770: mean batch inertia: 0.2712899780273437, ewa inertia: 0.2815659458524652
# Minibatch step 2327/400770: mean batch inertia: 0.2699986877441406, ewa inertia: 0.28156017334198774
# Minibatch step 2328/400770: mean batch inertia: 0.2708773193359375, ewa inertia: 0.28155484218346244
# Minibatch step 2329/400770: mean batch inertia: 0.2690164184570312, ewa inertia: 0.28154858502367114
# Minibatch step 2330/400770: mean batch inertia: 0.2736780090332031, ewa inertia: 0.28154465730096084
# Minibatch step 2331/400770: mean batch inertia: 0.2698086242675781, ewa inertia: 0.28153880056524927
# Minibatch step 2332/400770: mean batch inertia: 0.2706747131347656, ewa inertia: 0.2815333789642153
# Minibatch step 2333/400770: mean batch inertia: 0.26953955078125, ewa inertia: 0.28152739357872447
# Minibatch step 2334/400770: mean batch inertia: 0.27182470703125, ewa inertia: 0.28152255156178063
# Minibatch step 2335/400770: mean batch inertia: 0.268973388671875, ewa inertia: 0.2815162890427302
# Minibatch step 2336/400770: mean batch inertia: 0.26983880615234374, ewa inertia: 0.28151046152581105
# Minibatch step 2337/400770: mean batch inertia: 0.269728515625, ewa inertia: 0.28150458187779764
# Minibatch step 2338/400770: mean batch inertia: 0.2739969482421875, ewa inertia: 0.28150083527740055
# Minibatch step 2339/400770: mean batch inertia: 0.2710013427734375, ewa inertia: 0.28149559562337717
# Minibatch step 2340/400770: mean batch inertia: 0.266388671875, ewa inertia: 0.2814880566824456
# Minibatch step 2341/400770: mean batch inertia: 0.2688815307617187, ewa inertia: 0.28148176553701776
# Minibatch step 2342/400770: mean batch inertia: 0.27144393920898435, ewa inertia: 0.2814767562723237
# Minibatch step 2343/400770: mean batch inertia: 0.27027777099609374, ewa inertia: 0.28147116754427437
# Minibatch step 2344/400770: mean batch inertia: 0.27437750244140624, ewa inertia: 0.28146762753023247
# Minibatch step 2345/400770: mean batch inertia: 0.2716885986328125, ewa inertia: 0.28146274741549476
# Minibatch step 2346/400770: mean batch inertia: 0.2696585388183594, ewa inertia: 0.2814568566575324
# Minibatch step 2347/400770: mean batch inertia: 0.2729215698242187, ewa inertia: 0.28145259721832805
# Minibatch step 2348/400770: mean batch inertia: 0.271517333984375, ewa inertia: 0.28144763913659626
# Minibatch step 2349/400770: mean batch inertia: 0.27324609375, ewa inertia: 0.2814435462473193
# Minibatch step 2350/400770: mean batch inertia: 0.27182611083984376, ewa inertia: 0.28143874677400116
# Minibatch step 2351/400770: mean batch inertia: 0.2731966247558594, ewa inertia: 0.28143463363541116
# Minibatch step 2352/400770: mean batch inertia: 0.2725837707519531, ewa inertia: 0.28143021671151697
# Minibatch step 2353/400770: mean batch inertia: 0.2708621520996094, ewa inertia: 0.2814249428373519
# Minibatch step 2354/400770: mean batch inertia: 0.27211834716796873, ewa inertia: 0.2814202984851202
# Minibatch step 2355/400770: mean batch inertia: 0.27060479736328125, ewa inertia: 0.2814149011305389
# Minibatch step 2356/400770: mean batch inertia: 0.26947525024414065, ewa inertia: 0.28140894278162054
# Minibatch step 2357/400770: mean batch inertia: 0.26809521484375, ewa inertia: 0.2814022987149545
# Minibatch step 2358/400770: mean batch inertia: 0.271530029296875, ewa inertia: 0.2813973720695803
# Minibatch step 2359/400770: mean batch inertia: 0.2699425659179687, ewa inertia: 0.2813916556769912
# Minibatch step 2360/400770: mean batch inertia: 0.27205242919921874, ewa inertia: 0.28138699504072034
# Minibatch step 2361/400770: mean batch inertia: 0.26702633666992187, ewa inertia: 0.281379828515159
# Minibatch step 2362/400770: mean batch inertia: 0.2697879333496094, ewa inertia: 0.2813740437098344
# Minibatch step 2363/400770: mean batch inertia: 0.27008856201171877, ewa inertia: 0.28136841181671546
# Minibatch step 2364/400770: mean batch inertia: 0.2713848876953125, ewa inertia: 0.28136342965092886
# Minibatch step 2365/400770: mean batch inertia: 0.26906060791015624, ewa inertia: 0.2813572900656671
# Minibatch step 2366/400770: mean batch inertia: 0.2694278869628906, ewa inertia: 0.2813513368307903
# Minibatch step 2367/400770: mean batch inertia: 0.27118338012695314, ewa inertia: 0.2813462626259911
# Minibatch step 2368/400770: mean batch inertia: 0.2717810363769531, ewa inertia: 0.28134148920706814
# Minibatch step 2369/400770: mean batch inertia: 0.2710410461425781, ewa inertia: 0.281336348886436
# Minibatch step 2370/400770: mean batch inertia: 0.27013592529296876, ewa inertia: 0.2813307594406106
# Minibatch step 2371/400770: mean batch inertia: 0.26807196044921877, ewa inertia: 0.2813241427856195
# Minibatch step 2372/400770: mean batch inertia: 0.27281185913085937, ewa inertia: 0.2813198948258936
# Minibatch step 2373/400770: mean batch inertia: 0.27121194458007813, ewa inertia: 0.28131485056664457
# Minibatch step 2374/400770: mean batch inertia: 0.2712371826171875, ewa inertia: 0.281309821419436
# Minibatch step 2375/400770: mean batch inertia: 0.27017520141601564, ewa inertia: 0.2813042648121545
# Minibatch step 2376/400770: mean batch inertia: 0.26936041259765625, ewa inertia: 0.2812983043666104
# Minibatch step 2377/400770: mean batch inertia: 0.2704674987792969, ewa inertia: 0.2812928993745072
# Minibatch step 2378/400770: mean batch inertia: 0.27109780883789064, ewa inertia: 0.28128781162887295
# Minibatch step 2379/400770: mean batch inertia: 0.26815731811523436, ewa inertia: 0.2812812590032921
# Minibatch step 2380/400770: mean batch inertia: 0.26772671508789064, ewa inertia: 0.2812744947601123
# Minibatch step 2381/400770: mean batch inertia: 0.2693365478515625, ewa inertia: 0.28126853726154494
# Minibatch step 2382/400770: mean batch inertia: 0.2700889892578125, ewa inertia: 0.2812629582334486
# Minibatch step 2383/400770: mean batch inertia: 0.2686174011230469, ewa inertia: 0.2812566476099431
# Minibatch step 2384/400770: mean batch inertia: 0.2710818176269531, ewa inertia: 0.281251569975111
# Minibatch step 2385/400770: mean batch inertia: 0.26830792236328127, ewa inertia: 0.2812451105928827
# Minibatch step 2386/400770: mean batch inertia: 0.270521728515625, ewa inertia: 0.28123975920927785
# Minibatch step 2387/400770: mean batch inertia: 0.2701502990722656, ewa inertia: 0.28123422513852137
# Minibatch step 2388/400770: mean batch inertia: 0.26970068359375, ewa inertia: 0.281228469453917
# Minibatch step 2389/400770: mean batch inertia: 0.27102572631835936, ewa inertia: 0.28122337788933904
# Minibatch step 2390/400770: mean batch inertia: 0.2718201599121094, ewa inertia: 0.2812186853188278
# Minibatch step 2391/400770: mean batch inertia: 0.2715240783691406, ewa inertia: 0.2812138473339167
# Minibatch step 2392/400770: mean batch inertia: 0.2681606750488281, ewa inertia: 0.28120733329462805
# Minibatch step 2393/400770: mean batch inertia: 0.2704193115234375, ewa inertia: 0.2812019496533086
# Minibatch step 2394/400770: mean batch inertia: 0.26675311279296876, ewa inertia: 0.2811947391232606
# Minibatch step 2395/400770: mean batch inertia: 0.27298876953125, ewa inertia: 0.28119064402613353
# Minibatch step 2396/400770: mean batch inertia: 0.26881851196289064, ewa inertia: 0.2811844698523325
# Minibatch step 2397/400770: mean batch inertia: 0.27201837158203124, ewa inertia: 0.2811798956137527
# Minibatch step 2398/400770: mean batch inertia: 0.2714456787109375, ewa inertia: 0.2811750378619385
# Minibatch step 2399/400770: mean batch inertia: 0.2694818115234375, ewa inertia: 0.281169202488428
# Minibatch step 2400/400770: mean batch inertia: 0.27127508544921874, ewa inertia: 0.28116426494024344
# Minibatch step 2401/400770: mean batch inertia: 0.27167669677734374, ewa inertia: 0.2811595302757177
# Minibatch step 2402/400770: mean batch inertia: 0.27241671752929686, ewa inertia: 0.2811551672730331
# Minibatch step 2403/400770: mean batch inertia: 0.2714974670410156, ewa inertia: 0.2811503477060056
# Minibatch step 2404/400770: mean batch inertia: 0.2700403747558594, ewa inertia: 0.28114480339855974
# Minibatch step 2405/400770: mean batch inertia: 0.2695229187011719, ewa inertia: 0.2811390036272955
# Minibatch step 2406/400770: mean batch inertia: 0.26916644287109376, ewa inertia: 0.2811330288550755
# Minibatch step 2407/400770: mean batch inertia: 0.2662592163085937, ewa inertia: 0.28112560624567584
# Minibatch step 2408/400770: mean batch inertia: 0.2685841979980469, ewa inertia: 0.2811193475964927
# Minibatch step 2409/400770: mean batch inertia: 0.2715685119628906, ewa inertia: 0.281114581359045
# Minibatch step 2410/400770: mean batch inertia: 0.273983642578125, ewa inertia: 0.28111102274399197
# Minibatch step 2411/400770: mean batch inertia: 0.27231658935546876, ewa inertia: 0.2811066339806046
# Minibatch step 2412/400770: mean batch inertia: 0.2710534362792969, ewa inertia: 0.28110161704499903
# Minibatch step 2413/400770: mean batch inertia: 0.27047930908203127, ewa inertia: 0.28109631610129776
# Minibatch step 2414/400770: mean batch inertia: 0.27007861328125, ewa inertia: 0.2810908178402259
# Minibatch step 2415/400770: mean batch inertia: 0.27103170776367186, ewa inertia: 0.28108579795411576
# Minibatch step 2416/400770: mean batch inertia: 0.2683253784179688, ewa inertia: 0.28107943000980445
# Minibatch step 2417/400770: mean batch inertia: 0.26634213256835937, ewa inertia: 0.28107207552673746
# Minibatch step 2418/400770: mean batch inertia: 0.270302978515625, ewa inertia: 0.28106670132960737
# Minibatch step 2419/400770: mean batch inertia: 0.27618267822265624, ewa inertia: 0.28106426401263107
# Minibatch step 2420/400770: mean batch inertia: 0.27401333618164064, ewa inertia: 0.28106074532614556
# Minibatch step 2421/400770: mean batch inertia: 0.27041436767578125, ewa inertia: 0.2810554323707366
# Minibatch step 2422/400770: mean batch inertia: 0.2760895080566406, ewa inertia: 0.2810529541818811
# Minibatch step 2423/400770: mean batch inertia: 0.2701878967285156, ewa inertia: 0.2810475320967681
# Minibatch step 2424/400770: mean batch inertia: 0.26598367309570314, ewa inertia: 0.2810400146468159
# Minibatch step 2425/400770: mean batch inertia: 0.27190362548828123, ewa inertia: 0.2810354552342352
# Minibatch step 2426/400770: mean batch inertia: 0.2696952819824219, ewa inertia: 0.2810297960479095
# Minibatch step 2427/400770: mean batch inertia: 0.2695095825195313, ewa inertia: 0.28102404701450234
# Minibatch step 2428/400770: mean batch inertia: 0.27112478637695314, ewa inertia: 0.2810191068994627
# Minibatch step 2429/400770: mean batch inertia: 0.26739874267578123, ewa inertia: 0.28101230980939595
# Minibatch step 2430/400770: mean batch inertia: 0.26879812622070315, ewa inertia: 0.28100621445801033
# Minibatch step 2431/400770: mean batch inertia: 0.27050872802734377, ewa inertia: 0.28100097580509537
# Minibatch step 2432/400770: mean batch inertia: 0.2719963684082031, ewa inertia: 0.2809964821567254
# Minibatch step 2433/400770: mean batch inertia: 0.27109466552734374, ewa inertia: 0.28099154076614663
# Minibatch step 2434/400770: mean batch inertia: 0.26754013061523435, ewa inertia: 0.2809848279907157
# Minibatch step 2435/400770: mean batch inertia: 0.27155523681640625, ewa inertia: 0.28098012225895613
# Minibatch step 2436/400770: mean batch inertia: 0.2727802734375, ewa inertia: 0.280976030216331
# Minibatch step 2437/400770: mean batch inertia: 0.26720556640625, ewa inertia: 0.28096915822074847
# Minibatch step 2438/400770: mean batch inertia: 0.26692575073242186, ewa inertia: 0.28096215001568325
# Minibatch step 2439/400770: mean batch inertia: 0.27279977416992185, ewa inertia: 0.2809580766735265
# Minibatch step 2440/400770: mean batch inertia: 0.2692847900390625, ewa inertia: 0.28095225125070183
# Minibatch step 2441/400770: mean batch inertia: 0.26845144653320313, ewa inertia: 0.2809460128642552
# Minibatch step 2442/400770: mean batch inertia: 0.2729117736816406, ewa inertia: 0.2809420034672637
# Minibatch step 2443/400770: mean batch inertia: 0.270305419921875, ewa inertia: 0.28093669539949306
# Minibatch step 2444/400770: mean batch inertia: 0.2706630859375, ewa inertia: 0.2809315684698694
# Minibatch step 2445/400770: mean batch inertia: 0.27297235107421874, ewa inertia: 0.2809275965116596
# Minibatch step 2446/400770: mean batch inertia: 0.27140948486328126, ewa inertia: 0.28092284660474987
# Minibatch step 2447/400770: mean batch inertia: 0.27030307006835935, ewa inertia: 0.28091754692432863
# Minibatch step 2448/400770: mean batch inertia: 0.27099847412109374, ewa inertia: 0.28091259692224974
# Minibatch step 2449/400770: mean batch inertia: 0.2721261901855469, ewa inertia: 0.280908212164473
# Minibatch step 2450/400770: mean batch inertia: 0.2709641418457031, ewa inertia: 0.2809032496876642
# Minibatch step 2451/400770: mean batch inertia: 0.2709499816894531, ewa inertia: 0.2808982826208567
# Minibatch step 2452/400770: mean batch inertia: 0.27161480712890623, ewa inertia: 0.28089364980649034
# Minibatch step 2453/400770: mean batch inertia: 0.26734686279296876, ewa inertia: 0.2808868894343055
# Minibatch step 2454/400770: mean batch inertia: 0.26992498779296875, ewa inertia: 0.28088141902018626
# Minibatch step 2455/400770: mean batch inertia: 0.27364315795898436, ewa inertia: 0.28087780684715247
# Minibatch step 2456/400770: mean batch inertia: 0.26812319946289065, ewa inertia: 0.28087144180333035
# Minibatch step 2457/400770: mean batch inertia: 0.27119577026367186, ewa inertia: 0.2808666132679233
# Minibatch step 2458/400770: mean batch inertia: 0.2728450927734375, ewa inertia: 0.2808626102180505
# Minibatch step 2459/400770: mean batch inertia: 0.27047860717773436, ewa inertia: 0.28085742819774917
# Minibatch step 2460/400770: mean batch inertia: 0.26837380981445313, ewa inertia: 0.28085119838795
# Minibatch step 2461/400770: mean batch inertia: 0.27012274169921874, ewa inertia: 0.2808458444719172
# Minibatch step 2462/400770: mean batch inertia: 0.27218658447265626, ewa inertia: 0.2808415231652943
# Minibatch step 2463/400770: mean batch inertia: 0.2703218994140625, ewa inertia: 0.2808362734649977
# Minibatch step 2464/400770: mean batch inertia: 0.2705388488769531, ewa inertia: 0.28083113465070236
# Minibatch step 2465/400770: mean batch inertia: 0.271365478515625, ewa inertia: 0.2808264109211284
# Minibatch step 2466/400770: mean batch inertia: 0.2692111511230469, ewa inertia: 0.28082061445594586
# Minibatch step 2467/400770: mean batch inertia: 0.2709043884277344, ewa inertia: 0.28081566587451817
# Minibatch step 2468/400770: mean batch inertia: 0.2703394470214844, ewa inertia: 0.2808104378349494
# Minibatch step 2469/400770: mean batch inertia: 0.27225311279296877, ewa inertia: 0.28080616739782416
# Minibatch step 2470/400770: mean batch inertia: 0.27246527099609374, ewa inertia: 0.28080200496698543
# Minibatch step 2471/400770: mean batch inertia: 0.2739183349609375, ewa inertia: 0.28079856974864237
# Minibatch step 2472/400770: mean batch inertia: 0.2680771484375, ewa inertia: 0.28079222126595804
# Minibatch step 2473/400770: mean batch inertia: 0.27063851928710936, ewa inertia: 0.28078715417481953
# Minibatch step 2474/400770: mean batch inertia: 0.2708590087890625, ewa inertia: 0.2807821996451701
# Minibatch step 2475/400770: mean batch inertia: 0.26702935791015625, ewa inertia: 0.2807753364436866
# Minibatch step 2476/400770: mean batch inertia: 0.27263128662109376, ewa inertia: 0.2807712722469263
# Minibatch step 2477/400770: mean batch inertia: 0.26844903564453126, ewa inertia: 0.2807651229728955
# Minibatch step 2478/400770: mean batch inertia: 0.27183502197265624, ewa inertia: 0.2807606665061075
# Minibatch step 2479/400770: mean batch inertia: 0.2682796630859375, ewa inertia: 0.2807544380012763
# Minibatch step 2480/400770: mean batch inertia: 0.26895556640625, ewa inertia: 0.28074854990668496
# Minibatch step 2481/400770: mean batch inertia: 0.27347039794921874, ewa inertia: 0.2807449178265466
# Minibatch step 2482/400770: mean batch inertia: 0.2714882507324219, ewa inertia: 0.2807402983906106
# Minibatch step 2483/400770: mean batch inertia: 0.2706755065917969, ewa inertia: 0.28073527566910067
# Minibatch step 2484/400770: mean batch inertia: 0.2719955139160156, ewa inertia: 0.28073091418898
# Minibatch step 2485/400770: mean batch inertia: 0.267837646484375, ewa inertia: 0.2807244799482796
# Minibatch step 2486/400770: mean batch inertia: 0.27294564819335937, ewa inertia: 0.28072059800950144
# Minibatch step 2487/400770: mean batch inertia: 0.2726820678710937, ewa inertia: 0.28071658647115655
# Minibatch step 2488/400770: mean batch inertia: 0.2678251342773437, ewa inertia: 0.28071015313646647
# Minibatch step 2489/400770: mean batch inertia: 0.27064398193359374, ewa inertia: 0.2807051297265804
# Minibatch step 2490/400770: mean batch inertia: 0.26735955810546874, ewa inertia: 0.2806984697686813
# Minibatch step 2491/400770: mean batch inertia: 0.2679579772949219, ewa inertia: 0.28069211176874703
# Minibatch step 2492/400770: mean batch inertia: 0.27296383666992186, ewa inertia: 0.28068825505970135
# Minibatch step 2493/400770: mean batch inertia: 0.2710699462890625, ewa inertia: 0.28068345515054105
# Minibatch step 2494/400770: mean batch inertia: 0.2718441772460938, ewa inertia: 0.28067904400800076
# Minibatch step 2495/400770: mean batch inertia: 0.27042929077148437, ewa inertia: 0.280673928983559
# Minibatch step 2496/400770: mean batch inertia: 0.2659222412109375, ewa inertia: 0.28066656731915857
# Minibatch step 2497/400770: mean batch inertia: 0.27018386840820313, ewa inertia: 0.2806613360457895
# Minibatch step 2498/400770: mean batch inertia: 0.2736083068847656, ewa inertia: 0.28065781631065884
# Minibatch step 2499/400770: mean batch inertia: 0.27149481201171877, ewa inertia: 0.28065324361609073
# Minibatch step 2500/400770: mean batch inertia: 0.2706869506835938, ewa inertia: 0.2806482700493358
# Minibatch step 2501/400770: mean batch inertia: 0.2694582214355469, ewa inertia: 0.2806426857810277
# Minibatch step 2502/400770: mean batch inertia: 0.27115371704101565, ewa inertia: 0.2806379504175596
# Minibatch step 2503/400770: mean batch inertia: 0.2701514587402344, ewa inertia: 0.28063271725145306
# Minibatch step 2504/400770: mean batch inertia: 0.2686604919433594, ewa inertia: 0.28062674264663473
# Minibatch step 2505/400770: mean batch inertia: 0.2699003295898437, ewa inertia: 0.28062138975045353
# Minibatch step 2506/400770: mean batch inertia: 0.2714657287597656, ewa inertia: 0.28061682072048105
# Minibatch step 2507/400770: mean batch inertia: 0.26950433349609376, ewa inertia: 0.2806112751583148
# Minibatch step 2508/400770: mean batch inertia: 0.26813214111328126, ewa inertia: 0.28060504758637433
# Minibatch step 2509/400770: mean batch inertia: 0.269868408203125, ewa inertia: 0.28059968958685955
# Minibatch step 2510/400770: mean batch inertia: 0.268401611328125, ewa inertia: 0.2805936022726583
# Minibatch step 2511/400770: mean batch inertia: 0.2696616516113281, ewa inertia: 0.2805881468052398
# Minibatch step 2512/400770: mean batch inertia: 0.2713595886230469, ewa inertia: 0.2805835413967412
# Minibatch step 2513/400770: mean batch inertia: 0.2698919982910156, ewa inertia: 0.2805782059020181
# Minibatch step 2514/400770: mean batch inertia: 0.2686219482421875, ewa inertia: 0.28057223926567565
# Minibatch step 2515/400770: mean batch inertia: 0.2719681701660156, ewa inertia: 0.2805679455014524
# Minibatch step 2516/400770: mean batch inertia: 0.27077545166015626, ewa inertia: 0.28056305866718545
# Minibatch step 2517/400770: mean batch inertia: 0.268836181640625, ewa inertia: 0.2805572065006764
# Minibatch step 2518/400770: mean batch inertia: 0.26903936767578124, ewa inertia: 0.2805514586523383
# Minibatch step 2519/400770: mean batch inertia: 0.27134347534179687, ewa inertia: 0.28054686351149877
# Minibatch step 2520/400770: mean batch inertia: 0.2713111572265625, ewa inertia: 0.2805422545358196
# Minibatch step 2521/400770: mean batch inertia: 0.2681080627441406, ewa inertia: 0.2805360493918068
# Minibatch step 2522/400770: mean batch inertia: 0.2679617614746094, ewa inertia: 0.2805297743343932
# Minibatch step 2523/400770: mean batch inertia: 0.2706597900390625, ewa inertia: 0.2805248488293839
# Minibatch step 2524/400770: mean batch inertia: 0.27132122802734376, ewa inertia: 0.28052025586560525
# Minibatch step 2525/400770: mean batch inertia: 0.2732948608398437, ewa inertia: 0.2805166501132222
# Minibatch step 2526/400770: mean batch inertia: 0.26786944580078126, ewa inertia: 0.280510338667699
# Minibatch step 2527/400770: mean batch inertia: 0.27127578735351565, ewa inertia: 0.28050573026839504
# Minibatch step 2528/400770: mean batch inertia: 0.26538787841796874, ewa inertia: 0.2804981858739166
# Minibatch step 2529/400770: mean batch inertia: 0.27280145263671873, ewa inertia: 0.2804943449054833
# Minibatch step 2530/400770: mean batch inertia: 0.27006063842773437, ewa inertia: 0.2804891380812388
# Minibatch step 2531/400770: mean batch inertia: 0.2708813781738281, ewa inertia: 0.2804843434363705
# Minibatch step 2532/400770: mean batch inertia: 0.27411688232421877, ewa inertia: 0.2804811658262887
# Minibatch step 2533/400770: mean batch inertia: 0.26788653564453124, ewa inertia: 0.280474880617296
# Minibatch step 2534/400770: mean batch inertia: 0.271765625, ewa inertia: 0.2804705343609204
# Minibatch step 2535/400770: mean batch inertia: 0.272527587890625, ewa inertia: 0.2804665705225335
# Minibatch step 2536/400770: mean batch inertia: 0.27161651611328125, ewa inertia: 0.2804621540020993
# Minibatch step 2537/400770: mean batch inertia: 0.27013253784179686, ewa inertia: 0.2804569991229607
# Minibatch step 2538/400770: mean batch inertia: 0.271976806640625, ewa inertia: 0.28045276717797457
# Minibatch step 2539/400770: mean batch inertia: 0.27354434204101563, ewa inertia: 0.28044931960586095
# Minibatch step 2540/400770: mean batch inertia: 0.2692507629394531, ewa inertia: 0.28044373109170456
# Minibatch step 2541/400770: mean batch inertia: 0.26947018432617187, ewa inertia: 0.28043825486621665
# Minibatch step 2542/400770: mean batch inertia: 0.2688606262207031, ewa inertia: 0.28043247718043895
# Minibatch step 2543/400770: mean batch inertia: 0.2727318115234375, ewa inertia: 0.28042863424957565
# Minibatch step 2544/400770: mean batch inertia: 0.2713143615722656, ewa inertia: 0.28042408587397694
# Minibatch step 2545/400770: mean batch inertia: 0.27127923583984376, ewa inertia: 0.2804195222390911
# Minibatch step 2546/400770: mean batch inertia: 0.270407470703125, ewa inertia: 0.2804145258370181
# Minibatch step 2547/400770: mean batch inertia: 0.2683064880371094, ewa inertia: 0.2804084834564983
# Minibatch step 2548/400770: mean batch inertia: 0.27219912719726563, ewa inertia: 0.28040438666929296
# Minibatch step 2549/400770: mean batch inertia: 0.2695379028320313, ewa inertia: 0.2803989638723591
# Minibatch step 2550/400770: mean batch inertia: 0.2686078796386719, ewa inertia: 0.2803930796639631
# Minibatch step 2551/400770: mean batch inertia: 0.26916339111328125, ewa inertia: 0.2803874756137889
# Minibatch step 2552/400770: mean batch inertia: 0.27238839721679686, ewa inertia: 0.2803834837633933
# Minibatch step 2553/400770: mean batch inertia: 0.26932003784179687, ewa inertia: 0.28037796267473936
# Minibatch step 2554/400770: mean batch inertia: 0.26817007446289065, ewa inertia: 0.28037187046499096
# Minibatch step 2555/400770: mean batch inertia: 0.2725730590820313, ewa inertia: 0.2803679785556034
# Minibatch step 2556/400770: mean batch inertia: 0.27115463256835937, ewa inertia: 0.28036338073858014
# Minibatch step 2557/400770: mean batch inertia: 0.2703343200683594, ewa inertia: 0.2803583758482894
# Minibatch step 2558/400770: mean batch inertia: 0.26912396240234376, ewa inertia: 0.2803527694402092
# Minibatch step 2559/400770: mean batch inertia: 0.2733321228027344, ewa inertia: 0.28034926586521386
# Minibatch step 2560/400770: mean batch inertia: 0.26938482666015623, ewa inertia: 0.2803437941847519
# Minibatch step 2561/400770: mean batch inertia: 0.2737265625, ewa inertia: 0.28034049192946603
# Minibatch step 2562/400770: mean batch inertia: 0.269960205078125, ewa inertia: 0.2803353117636872
# Minibatch step 2563/400770: mean batch inertia: 0.2714263000488281, ewa inertia: 0.2803308658212706
# Minibatch step 2564/400770: mean batch inertia: 0.26657305908203127, ewa inertia: 0.28032400014205733
# Minibatch step 2565/400770: mean batch inertia: 0.27409375, ewa inertia: 0.28032089100557184
# Minibatch step 2566/400770: mean batch inertia: 0.2770831604003906, ewa inertia: 0.2803192752524118
# Minibatch step 2567/400770: mean batch inertia: 0.26709909057617187, ewa inertia: 0.2803126778674618
# Minibatch step 2568/400770: mean batch inertia: 0.27077780151367187, ewa inertia: 0.2803079195943138
# Minibatch step 2569/400770: mean batch inertia: 0.26685671997070315, ewa inertia: 0.2803012069239442
# Minibatch step 2570/400770: mean batch inertia: 0.26877813720703125, ewa inertia: 0.2802954564651881
# Minibatch step 2571/400770: mean batch inertia: 0.26905648803710935, ewa inertia: 0.2802898477839951
# Minibatch step 2572/400770: mean batch inertia: 0.271175537109375, ewa inertia: 0.2802852993894343
# Minibatch step 2573/400770: mean batch inertia: 0.2735312194824219, ewa inertia: 0.2802819288415773
# Minibatch step 2574/400770: mean batch inertia: 0.27436273193359373, ewa inertia: 0.280278974932721
# Minibatch step 2575/400770: mean batch inertia: 0.269978759765625, ewa inertia: 0.2802738347258185
# Minibatch step 2576/400770: mean batch inertia: 0.26946612548828125, ewa inertia: 0.2802684412596897
# Minibatch step 2577/400770: mean batch inertia: 0.26918405151367186, ewa inertia: 0.28026290971925505
# Minibatch step 2578/400770: mean batch inertia: 0.2698316955566406, ewa inertia: 0.28025770413877243
# Minibatch step 2579/400770: mean batch inertia: 0.2749792175292969, ewa inertia: 0.28025506996920757
# Minibatch step 2580/400770: mean batch inertia: 0.26821652221679687, ewa inertia: 0.280249062266917
# Minibatch step 2581/400770: mean batch inertia: 0.2691710205078125, ewa inertia: 0.280243533894374
# Minibatch step 2582/400770: mean batch inertia: 0.26809561157226564, ewa inertia: 0.2802374716099306
# Minibatch step 2583/400770: mean batch inertia: 0.2743749389648438, ewa inertia: 0.2802345459787394
# Minibatch step 2584/400770: mean batch inertia: 0.2716730651855469, ewa inertia: 0.2802302734677331
# Minibatch step 2585/400770: mean batch inertia: 0.27304461669921876, ewa inertia: 0.2802266875462818
# Minibatch step 2586/400770: mean batch inertia: 0.2732930908203125, ewa inertia: 0.28022322741256894
# Minibatch step 2587/400770: mean batch inertia: 0.2724417114257813, ewa inertia: 0.28021934413425503
# Minibatch step 2588/400770: mean batch inertia: 0.2688602905273437, ewa inertia: 0.2802136755258999
# Minibatch step 2589/400770: mean batch inertia: 0.27173446655273437, ewa inertia: 0.28020944407172294
# Minibatch step 2590/400770: mean batch inertia: 0.26778521728515625, ewa inertia: 0.2802032439006342
# Minibatch step 2591/400770: mean batch inertia: 0.26898013305664065, ewa inertia: 0.2801976431329908
# Minibatch step 2592/400770: mean batch inertia: 0.2720299072265625, ewa inertia: 0.2801935671159559
# Minibatch step 2593/400770: mean batch inertia: 0.2716373291015625, ewa inertia: 0.28018929722129954
# Minibatch step 2594/400770: mean batch inertia: 0.269319580078125, ewa inertia: 0.2801838728108206
# Minibatch step 2595/400770: mean batch inertia: 0.27313589477539063, ewa inertia: 0.2801803555963975
# Minibatch step 2596/400770: mean batch inertia: 0.26864230346679685, ewa inertia: 0.28017459766083636
# Minibatch step 2597/400770: mean batch inertia: 0.27150711059570315, ewa inertia: 0.2801702722485884
# Minibatch step 2598/400770: mean batch inertia: 0.2731695861816406, ewa inertia: 0.280166778634692
# Minibatch step 2599/400770: mean batch inertia: 0.2723460388183594, ewa inertia: 0.2801628757821657
# Minibatch step 2600/400770: mean batch inertia: 0.264451904296875, ewa inertia: 0.28015503539798303
# Minibatch step 2601/400770: mean batch inertia: 0.2706796264648437, ewa inertia: 0.28015030680138464
# Minibatch step 2602/400770: mean batch inertia: 0.27210675048828126, ewa inertia: 0.28014629275478364
# ...
# Minibatch step 6965/400770: mean batch inertia: 0.27120513916015626, ewa inertia: 0.2713747315919604
# Minibatch step 6966/400770: mean batch inertia: 0.269904296875, ewa inertia: 0.2713739977880001
# Minibatch step 6967/400770: mean batch inertia: 0.2732896423339844, ewa inertia: 0.27137495376893433
# Minibatch step 6968/400770: mean batch inertia: 0.2700884704589844, ewa inertia: 0.2713743117638614
# Minibatch step 6969/400770: mean batch inertia: 0.2682920227050781, ewa inertia: 0.2713727735820624
# Minibatch step 6970/400770: mean batch inertia: 0.2681518249511719, ewa inertia: 0.27137116620375856
# Minibatch step 6971/400770: mean batch inertia: 0.2686610717773438, ewa inertia: 0.27136981376151814
# Minibatch step 6972/400770: mean batch inertia: 0.2702340087890625, ewa inertia: 0.2713692469507803
# Minibatch step 6973/400770: mean batch inertia: 0.26933203125, ewa inertia: 0.2713682303011242
# Minibatch step 6974/400770: mean batch inertia: 0.2686834106445313, ewa inertia: 0.2713668904719743
# Minibatch step 6975/400770: mean batch inertia: 0.26695608520507813, ewa inertia: 0.27136468930905583
# Minibatch step 6976/400770: mean batch inertia: 0.2694665222167969, ewa inertia: 0.271363742050049
# Minibatch step 6977/400770: mean batch inertia: 0.273074951171875, ewa inertia: 0.2713645960097767
# Minibatch step 6978/400770: mean batch inertia: 0.27217913818359374, ewa inertia: 0.2713650024979167
# Minibatch step 6979/400770: mean batch inertia: 0.2686566162109375, ewa inertia: 0.27136365090810416
# Minibatch step 6980/400770: mean batch inertia: 0.26875149536132814, ewa inertia: 0.27136234734116366
# Minibatch step 6981/400770: mean batch inertia: 0.2681195373535156, ewa inertia: 0.27136072905319475
# Minibatch step 6982/400770: mean batch inertia: 0.2688541259765625, ewa inertia: 0.2713594781610311
# Minibatch step 6983/400770: mean batch inertia: 0.2697352294921875, ewa inertia: 0.2713586675979425
# Minibatch step 6984/400770: mean batch inertia: 0.26838055419921875, ewa inertia: 0.2713571814038388
# Minibatch step 6985/400770: mean batch inertia: 0.2692978210449219, ewa inertia: 0.27135615370313937
# Minibatch step 6986/400770: mean batch inertia: 0.2695568542480469, ewa inertia: 0.2713552557829184
# Minibatch step 6987/400770: mean batch inertia: 0.26858724975585935, ewa inertia: 0.271353874440543
# Minibatch step 6988/400770: mean batch inertia: 0.2688382568359375, ewa inertia: 0.2713526190497802
# Minibatch step 6989/400770: mean batch inertia: 0.27226971435546876, ewa inertia: 0.27135307671591086
# Minibatch step 6990/400770: mean batch inertia: 0.2677111511230469, ewa inertia: 0.2713512592537737
# Minibatch step 6991/400770: mean batch inertia: 0.26971063232421877, ewa inertia: 0.27135044051729773
# Minibatch step 6992/400770: mean batch inertia: 0.2707559814453125, ewa inertia: 0.27135014385916245
# Minibatch step 6993/400770: mean batch inertia: 0.2718392028808594, ewa inertia: 0.2713503879185844
# Minibatch step 6994/400770: mean batch inertia: 0.2696751403808594, ewa inertia: 0.2713495519050821
# Minibatch step 6995/400770: mean batch inertia: 0.26968869018554686, ewa inertia: 0.27134872307066105
# Minibatch step 6996/400770: mean batch inertia: 0.27192312622070314, ewa inertia: 0.2713490097201134
# Minibatch step 6997/400770: mean batch inertia: 0.2714068603515625, ewa inertia: 0.27134903858982246
# Minibatch step 6998/400770: mean batch inertia: 0.2681463317871094, ewa inertia: 0.2713474403148984
# Minibatch step 6999/400770: mean batch inertia: 0.2693482666015625, ewa inertia: 0.2713464426496697
# Minibatch step 7000/400770: mean batch inertia: 0.2687414245605469, ewa inertia: 0.27134514264459736
# Minibatch step 7001/400770: mean batch inertia: 0.2694962463378906, ewa inertia: 0.2713442199736237
# Minibatch step 7002/400770: mean batch inertia: 0.2703153076171875, ewa inertia: 0.2713437065064474
# Minibatch step 7003/400770: mean batch inertia: 0.2689055480957031, ewa inertia: 0.2713424897708269
# Minibatch step 7004/400770: mean batch inertia: 0.27344891357421874, ewa inertia: 0.2713435409580107
# Minibatch step 7005/400770: mean batch inertia: 0.2698294372558594, ewa inertia: 0.27134278536153295
# Minibatch step 7006/400770: mean batch inertia: 0.2688161926269531, ewa inertia: 0.2713415244937546
# Minibatch step 7007/400770: mean batch inertia: 0.27050979614257814, ewa inertia: 0.27134110942904555
# Minibatch step 7008/400770: mean batch inertia: 0.26919509887695314, ewa inertia: 0.27134003848653865
# Minibatch step 7009/400770: mean batch inertia: 0.2688050537109375, ewa inertia: 0.2713387734308063
# Minibatch step 7010/400770: mean batch inertia: 0.26963525390625, ewa inertia: 0.2713379233084859
# Minibatch step 7011/400770: mean batch inertia: 0.27145233154296877, ewa inertia: 0.2713379804026327
# Minibatch step 7012/400770: mean batch inertia: 0.270887451171875, ewa inertia: 0.271337755571071
# Minibatch step 7013/400770: mean batch inertia: 0.26795819091796874, ewa inertia: 0.27133606903721946
# Minibatch step 7014/400770: mean batch inertia: 0.2709294128417969, ewa inertia: 0.2713358661000042
# Minibatch step 7015/400770: mean batch inertia: 0.2690048828125, ewa inertia: 0.27133470284892747
# Minibatch step 7016/400770: mean batch inertia: 0.26988140869140625, ewa inertia: 0.2713339775987712
# Minibatch step 7017/400770: mean batch inertia: 0.26681277465820313, ewa inertia: 0.2713317213431313
# Minibatch step 7018/400770: mean batch inertia: 0.2668356018066406, ewa inertia: 0.2713294776050831
# Minibatch step 7019/400770: mean batch inertia: 0.2713997802734375, ewa inertia: 0.2713295126888416
# Minibatch step 7020/400770: mean batch inertia: 0.2683699035644531, ewa inertia: 0.27132803572908853
# Minibatch step 7021/400770: mean batch inertia: 0.27111016845703123, ewa inertia: 0.27132792700486896
# Minibatch step 7022/400770: mean batch inertia: 0.2664299011230469, ewa inertia: 0.27132548269996487
# Minibatch step 7023/400770: mean batch inertia: 0.271885986328125, ewa inertia: 0.2713257624130167
# Minibatch step 7024/400770: mean batch inertia: 0.26853399658203125, ewa inertia: 0.2713243692135775
# Minibatch step 7025/400770: mean batch inertia: 0.27149725341796876, ewa inertia: 0.2713244554895015
# Minibatch step 7026/400770: mean batch inertia: 0.2709486999511719, ewa inertia: 0.27132426797291276
# Minibatch step 7027/400770: mean batch inertia: 0.2707289428710937, ewa inertia: 0.2713239708825949
# Minibatch step 7028/400770: mean batch inertia: 0.2696148986816406, ewa inertia: 0.2713231179892736
# Minibatch step 7029/400770: mean batch inertia: 0.26913580322265623, ewa inertia: 0.27132202643436154
# Minibatch step 7030/400770: mean batch inertia: 0.27435906982421876, ewa inertia: 0.2713235420368167
# Minibatch step 7031/400770: mean batch inertia: 0.27133148193359374, ewa inertia: 0.2713235459991332
# Minibatch step 7032/400770: mean batch inertia: 0.2726394958496094, ewa inertia: 0.2713242027091529
# Minibatch step 7033/400770: mean batch inertia: 0.27006710815429685, ewa inertia: 0.27132357537020874
# Minibatch step 7034/400770: mean batch inertia: 0.2703806762695313, ewa inertia: 0.27132310482698346
# Minibatch step 7035/400770: mean batch inertia: 0.2706424560546875, ewa inertia: 0.27132276515684445
# Minibatch step 7036/400770: mean batch inertia: 0.2662522888183594, ewa inertia: 0.2713202347924733
# Minibatch step 7037/400770: mean batch inertia: 0.270217041015625, ewa inertia: 0.27131968425598696
# Minibatch step 7038/400770: mean batch inertia: 0.271798828125, ewa inertia: 0.27131992336736305
# Minibatch step 7039/400770: mean batch inertia: 0.27080596923828126, ewa inertia: 0.2713196668843169
# Minibatch step 7040/400770: mean batch inertia: 0.271131591796875, ewa inertia: 0.27131957302755305
# Minibatch step 7041/400770: mean batch inertia: 0.2718096008300781, ewa inertia: 0.27131981757043416
# Minibatch step 7042/400770: mean batch inertia: 0.2692443542480469, ewa inertia: 0.27131878183373137
# Minibatch step 7043/400770: mean batch inertia: 0.2683435974121094, ewa inertia: 0.2713172971013008
# Minibatch step 7044/400770: mean batch inertia: 0.26786849975585936, ewa inertia: 0.27131557601765033
# Minibatch step 7045/400770: mean batch inertia: 0.2655106201171875, ewa inertia: 0.2713126791194881
# Minibatch step 7046/400770: mean batch inertia: 0.2694109497070313, ewa inertia: 0.2713117300827453
# Minibatch step 7047/400770: mean batch inertia: 0.26876361083984374, ewa inertia: 0.2713104584724043
# Minibatch step 7048/400770: mean batch inertia: 0.2656358947753906, ewa inertia: 0.27130762664500935
# Minibatch step 7049/400770: mean batch inertia: 0.26980459594726564, ewa inertia: 0.2713068765743903
# Minibatch step 7050/400770: mean batch inertia: 0.2717981567382812, ewa inertia: 0.2713071217422483
# Minibatch step 7051/400770: mean batch inertia: 0.2718858947753906, ewa inertia: 0.27130741057244184
# Minibatch step 7052/400770: mean batch inertia: 0.2709320068359375, ewa inertia: 0.2713072232314159
# Minibatch step 7053/400770: mean batch inertia: 0.2704429931640625, ewa inertia: 0.27130679194708973
# Minibatch step 7054/400770: mean batch inertia: 0.2721061706542969, ewa inertia: 0.2713071908680717
# Minibatch step 7055/400770: mean batch inertia: 0.2736072998046875, ewa inertia: 0.2713083387116498
# Minibatch step 7056/400770: mean batch inertia: 0.2694775695800781, ewa inertia: 0.2713074250868396
# Minibatch step 7057/400770: mean batch inertia: 0.2681628723144531, ewa inertia: 0.2713058558330324
# Minibatch step 7058/400770: mean batch inertia: 0.2687859191894531, ewa inertia: 0.2713045982869017
# Minibatch step 7059/400770: mean batch inertia: 0.2683359375, ewa inertia: 0.2713031168100179
# Minibatch step 7060/400770: mean batch inertia: 0.26998541259765624, ewa inertia: 0.27130245922450363
# Minibatch step 7061/400770: mean batch inertia: 0.2677077026367187, ewa inertia: 0.27130066530152963
# Minibatch step 7062/400770: mean batch inertia: 0.26647817993164064, ewa inertia: 0.2712982586942711
# Minibatch step 7063/400770: mean batch inertia: 0.2702047424316406, ewa inertia: 0.2712977129872397
# Minibatch step 7064/400770: mean batch inertia: 0.269062744140625, ewa inertia: 0.27129659765109326
# Minibatch step 7065/400770: mean batch inertia: 0.2691731262207031, ewa inertia: 0.27129553795648237
# Minibatch step 7066/400770: mean batch inertia: 0.26997674560546875, ewa inertia: 0.2712948798279447
# Minibatch step 7067/400770: mean batch inertia: 0.2724394226074219, ewa inertia: 0.2712954509991872
# Minibatch step 7068/400770: mean batch inertia: 0.2697445068359375, ewa inertia: 0.27129467701789034
# Minibatch step 7069/400770: mean batch inertia: 0.27120663452148436, ewa inertia: 0.27129463308126955
# Minibatch step 7070/400770: mean batch inertia: 0.26951315307617185, ewa inertia: 0.2712937440536453
# Minibatch step 7071/400770: mean batch inertia: 0.27286477661132813, ewa inertia: 0.27129452805983023
# Minibatch step 7072/400770: mean batch inertia: 0.27259384155273436, ewa inertia: 0.27129517646766216
# Minibatch step 7073/400770: mean batch inertia: 0.27212881469726563, ewa inertia: 0.2712955924854747
# Minibatch step 7074/400770: mean batch inertia: 0.2661967468261719, ewa inertia: 0.271293047963712
# Minibatch step 7075/400770: mean batch inertia: 0.26972064208984375, ewa inertia: 0.2712922632721891
# Minibatch step 7076/400770: mean batch inertia: 0.27002606201171875, ewa inertia: 0.27129163138864554
# Minibatch step 7077/400770: mean batch inertia: 0.26673883056640624, ewa inertia: 0.2712893593644371
# Minibatch step 7078/400770: mean batch inertia: 0.2700451354980469, ewa inertia: 0.2712887384484657
# Minibatch step 7079/400770: mean batch inertia: 0.2688917236328125, ewa inertia: 0.27128754224509505
# Minibatch step 7080/400770: mean batch inertia: 0.269780029296875, ewa inertia: 0.2712867899376591
# Minibatch step 7081/400770: mean batch inertia: 0.266545654296875, ewa inertia: 0.27128442392707086
# Minibatch step 7082/400770: mean batch inertia: 0.2690103759765625, ewa inertia: 0.2712832890889357
# Minibatch step 7083/400770: mean batch inertia: 0.2739678649902344, ewa inertia: 0.2712846287964422
# Minibatch step 7084/400770: mean batch inertia: 0.26860733032226564, ewa inertia: 0.27128329272065416
# Minibatch step 7085/400770: mean batch inertia: 0.268300048828125, ewa inertia: 0.27128180396623497
# Minibatch step 7086/400770: mean batch inertia: 0.2706355285644531, ewa inertia: 0.2712814814497411
# Minibatch step 7087/400770: mean batch inertia: 0.2724905090332031, ewa inertia: 0.27128208480140215
# Minibatch step 7088/400770: mean batch inertia: 0.2702236328125, ewa inertia: 0.2712815565928035
# Minibatch step 7089/400770: mean batch inertia: 0.2696357116699219, ewa inertia: 0.27128073525234647
# Minibatch step 7090/400770: mean batch inertia: 0.2708102722167969, ewa inertia: 0.27128050047304303
# Minibatch step 7091/400770: mean batch inertia: 0.2707147216796875, ewa inertia: 0.2712802181274792
# Minibatch step 7092/400770: mean batch inertia: 0.2669742431640625, ewa inertia: 0.2712780692789484
# Minibatch step 7093/400770: mean batch inertia: 0.26951080322265625, ewa inertia: 0.27127718734463596
# Minibatch step 7094/400770: mean batch inertia: 0.26910025024414064, ewa inertia: 0.2712761009685818
# Minibatch step 7095/400770: mean batch inertia: 0.26984701538085937, ewa inertia: 0.2712753877994409
# Minibatch step 7096/400770: mean batch inertia: 0.2707168884277344, ewa inertia: 0.2712751090865908
# Minibatch step 7097/400770: mean batch inertia: 0.27014129638671874, ewa inertia: 0.2712745432700742
# Minibatch step 7098/400770: mean batch inertia: 0.2699124755859375, ewa inertia: 0.27127386354546673
# Minibatch step 7099/400770: mean batch inertia: 0.27237557983398436, ewa inertia: 0.2712744133446291
# Minibatch step 7100/400770: mean batch inertia: 0.2698656921386719, ewa inertia: 0.27127371033810455
# Minibatch step 7101/400770: mean batch inertia: 0.27237432861328126, ewa inertia: 0.2712742595893156
# Minibatch step 7102/400770: mean batch inertia: 0.27042953491210936, ewa inertia: 0.27127383803893573
# Minibatch step 7103/400770: mean batch inertia: 0.26901092529296877, ewa inertia: 0.2712727087576996
# Minibatch step 7104/400770: mean batch inertia: 0.2677052612304687, ewa inertia: 0.27127092846300616
# Minibatch step 7105/400770: mean batch inertia: 0.2698973083496094, ewa inertia: 0.2712702429732884
# Minibatch step 7106/400770: mean batch inertia: 0.26852044677734377, ewa inertia: 0.271268870718325
# Minibatch step 7107/400770: mean batch inertia: 0.26975442504882813, ewa inertia: 0.27126811495119224
# Minibatch step 7108/400770: mean batch inertia: 0.2708690185546875, ewa inertia: 0.27126791578660986
# Minibatch step 7109/400770: mean batch inertia: 0.26760751342773437, ewa inertia: 0.27126608910384975
# Minibatch step 7110/400770: mean batch inertia: 0.26911102294921874, ewa inertia: 0.2712650136422459
# Minibatch step 7111/400770: mean batch inertia: 0.2711820068359375, ewa inertia: 0.27126497221862983
# Minibatch step 7112/400770: mean batch inertia: 0.2703697509765625, ewa inertia: 0.2712645254685054
# Minibatch step 7113/400770: mean batch inertia: 0.273631591796875, ewa inertia: 0.2712657067264192
# Minibatch step 7114/400770: mean batch inertia: 0.2739212341308594, ewa inertia: 0.27126703193759905
# Minibatch step 7115/400770: mean batch inertia: 0.27176837158203127, ewa inertia: 0.2712672821255281
# Minibatch step 7116/400770: mean batch inertia: 0.27101513671875, ewa inertia: 0.27126715629518966
# Minibatch step 7117/400770: mean batch inertia: 0.2714064636230469, ewa inertia: 0.27126722581494983
# Minibatch step 7118/400770: mean batch inertia: 0.2723190612792969, ewa inertia: 0.2712677507216461
# Minibatch step 7119/400770: mean batch inertia: 0.2688186340332031, ewa inertia: 0.27126652851742006
# Minibatch step 7120/400770: mean batch inertia: 0.26915386962890625, ewa inertia: 0.27126547421868696
# Minibatch step 7121/400770: mean batch inertia: 0.27126876831054686, ewa inertia: 0.27126547586256655
# Minibatch step 7122/400770: mean batch inertia: 0.27011502075195315, ewa inertia: 0.27126490174084145
# Converged (lack of improvement in inertia) at step 7122/400770
# X_train shape: (12641, 300)
# X_test shape: (3162, 300)

# %%
from sklearn.model_selection import GridSearchCV


rf = RandomForestClassifier(
    class_weight="balanced",
    random_state=42,
    n_jobs=-1
)

param_grid_rf = {
    "n_estimators": [200, 500],
    "max_depth": [None, 20, 40],
    "min_samples_leaf": [1, 2, 5]
}

grid_rf = GridSearchCV(
    estimator=rf,
    param_grid=param_grid_rf,
    scoring="accuracy",
    cv=3,
    n_jobs=-1,
    verbose=2
)

print("Tìm tham số tốt nhất cho Random Forest...")
grid_rf.fit(X_train, y_train)

print("RF - best params:", grid_rf.best_params_)
print("RF - best CV accuracy:", grid_rf.best_score_)

# best_rf = grid_rf.best_estimator_


# Đánh giá trên test
y_pred_rf = best_rf.predict(X_test)
print("=== Random Forest trên tập test ===")
print(classification_report(y_test, y_pred_rf))
print("Confusion matrix:")
print(confusion_matrix(y_test, y_pred_rf))

# vẽ confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred_rf), annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Tìm tham số tốt nhất cho Random Forest...
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# RF - best params: {'max_depth': None, 'min_samples_leaf': 1, 'n_estimators': 500}
# RF - best CV accuracy: 0.7938453396803716
# === Random Forest trên tập test ===
#               precision    recall  f1-score   support
#
#          cat       0.80      0.78      0.79      1112
#          dog       0.77      0.79      0.78      1034
#         wild       0.83      0.82      0.82      1016
#
#     accuracy                           0.80      3162
#    macro avg       0.80      0.80      0.80      3162
# weighted avg       0.80      0.80      0.80      3162
#
# Confusion matrix:
# [[872 156  84]
#  [129 817  88]
#  [ 89  94 833]]

# %%
svm_pipeline = Pipeline([
    ("scaler", StandardScaler()),  # chuẩn hoá histogram trước khi vào SVM
    ("svm", SVC())
])

param_grid_svm = {
    "svm__C": [0.1, 1, 10, 100],
    "svm__gamma": [1e-3, 1e-4],
    "svm__kernel": ["rbf"]
}

grid_svm = GridSearchCV(
    estimator=svm_pipeline,
    param_grid=param_grid_svm,
    scoring="accuracy",
    cv=3,
    n_jobs=-1,
    verbose=2
)

print("Tìm tham số tốt nhất cho SVM...")
grid_svm.fit(X_train, y_train)

print("SVM - best params:", grid_svm.best_params_)
print("SVM - best CV accuracy:", grid_svm.best_score_)

best_svm = grid_svm.best_estimator_

# Đánh giá trên test
y_pred_svm = best_svm.predict(X_test)
print("=== SVM trên tập test ===")
print(classification_report(y_test, y_pred_svm))
print("Confusion matrix:")
print(confusion_matrix(y_test, y_pred_svm))

# vẽ confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred_svm), annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Tìm tham số tốt nhất cho SVM...
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# SVM - best params: {'svm__C': 100, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# SVM - best CV accuracy: 0.8559448829349856
# === SVM trên tập test ===
#               precision    recall  f1-score   support
#
#          cat       0.87      0.88      0.87      1112
#          dog       0.84      0.86      0.85      1034
#         wild       0.90      0.87      0.88      1016
#
#     accuracy                           0.87      3162
#    macro avg       0.87      0.87      0.87      3162
# weighted avg       0.87      0.87      0.87      3162
#
# Confusion matrix:
# [[973 100  39]
#  [ 84 886  64]
#  [ 56  72 888]]

# %% [markdown]
# # So sánh hai mô hình

# %%
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                             f1_score, classification_report, confusion_matrix)
rf_acc = accuracy_score(y_test, y_pred_rf)
rf_f1 = f1_score(y_test, y_pred_rf, average='macro')
svm_acc = accuracy_score(y_test, y_pred_svm)
svm_f1 = f1_score(y_test, y_pred_svm, average='macro')

models = ["Random Forest", "SVM"]
accs = [rf_acc, svm_acc]
f1s  = [rf_f1, svm_f1]

x = np.arange(len(models))
width = 0.35

fig, ax = plt.subplots(figsize=(7,5))

rects1 = ax.bar(x - width/2, accs, width, label='Accuracy', color='skyblue')
rects2 = ax.bar(x + width/2, f1s,  width, label='Macro-F1', color='orange')

ax.set_ylabel('Scores')
ax.set_title('So sánh kết quả giữa RF và SVM')
ax.set_xticks(x)
ax.set_xticklabels(models)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.4f}',
                    xy=(rect.get_x() + rect.get_width()/2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom')
autolabel(rects1)
autolabel(rects2)

plt.ylim(0, 1.15)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Task
# So sánh và phân tích kết quả dự đoán của mô hình Random Forest và SVM trên tập kiểm tra, bao gồm:
# 1. Xác định số lượng ảnh được phân loại đúng bởi cả hai mô hình.
# 2. Xác định số lượng ảnh được phân loại sai bởi cả hai mô hình.
# 3. Xác định số lượng ảnh được Random Forest phân loại đúng nhưng SVM phân loại sai.
# 4. Xác định số lượng ảnh được SVM phân loại đúng nhưng Random Forest phân loại sai.
# 5. Tổng hợp và hiển thị các thống kê trên.

# %% [markdown]
# ## So sánh dự đoán của hai mô hình
#
# ### Subtask:
# So sánh dự đoán của mô hình Random Forest và SVM với nhãn thực tế trên tập kiểm tra (y_test) để xác định các trường hợp: đúng ở cả hai, sai ở cả hai, đúng ở RF và sai ở SVM, sai ở RF và đúng ở SVM.

# %% [markdown]
# **Reasoning**:
# To compare the predictions of both models with the true labels, I will create boolean arrays for correct predictions for each model and then use logical operations to identify the indices for the four desired scenarios: both correct, both incorrect, RF correct/SVM incorrect, and SVM correct/RF incorrect. This directly addresses instructions 1-6.

# %%
import numpy as np

# 1. Mảng boolean cho biết khi nào dự đoán của Random Forest khớp với nhãn thực tế
rf_correct = (y_pred_rf == y_test)

# 2. Mảng boolean cho biết khi nào dự đoán của SVM khớp với nhãn thực tế
svm_correct = (y_pred_svm == y_test)

# 3. Chỉ mục mà cả hai mô hình đều dự đoán đúng
both_correct_indices = np.where(rf_correct & svm_correct)[0]
print(f"Cả hai mô hình dự đoán đúng: {len(both_correct_indices)} trường hợp")

# 4. Chỉ mục mà cả hai mô hình đều dự đoán sai
both_incorrect_indices = np.where(~rf_correct & ~svm_correct)[0]
print(f"Cả hai mô hình dự đoán sai: {len(both_incorrect_indices)} trường hợp")

# 5. Chỉ mục mà Random Forest dự đoán đúng và SVM dự đoán sai
rf_correct_svm_incorrect_indices = np.where(rf_correct & ~svm_correct)[0]
print(f"RF đúng, SVM sai: {len(rf_correct_svm_incorrect_indices)} trường hợp")

# 6. Chỉ mục mà SVM dự đoán đúng và Random Forest dự đoán sai
svm_correct_rf_incorrect_indices = np.where(svm_correct & ~rf_correct)[0]
print(f"SVM đúng, RF sai: {len(svm_correct_rf_incorrect_indices)} trường hợp")
# Out:
# Cả hai mô hình dự đoán đúng: 2392 trường hợp
# Cả hai mô hình dự đoán sai: 285 trường hợp
# RF đúng, SVM sai: 130 trường hợp
# SVM đúng, RF sai: 355 trường hợp

# %% [markdown]
# ## Phân tích và minh họa các trường hợp khác biệt
#
# ### Subtask:
# Tùy chọn hiển thị một vài ví dụ ảnh cho từng loại trường hợp (RF đúng/SVM sai, SVM đúng/RF sai, cả hai đều sai) để minh họa sự khác biệt trong hiệu suất dự đoán giữa hai mô hình.

# %% [markdown]
# **Reasoning**:
# I need to display example images for the 'RF correct/SVM incorrect' scenario. First, I'll select a random index from `rf_correct_svm_incorrect_indices`, then retrieve the image path, true label, and both model predictions, and finally display this information along with the image.

# %%
import random
from PIL import Image

# --- Case 1: RF correct, SVM incorrect ---
print("\n--- RF correct, SVM incorrect ---")
if len(rf_correct_svm_incorrect_indices) > 0:
    idx = random.choice(rf_correct_svm_incorrect_indices)
    img_path = test_paths[idx]
    true_label = y_test[idx]
    rf_pred = y_pred_rf[idx]
    svm_pred = y_pred_svm[idx]

    print(f"Ảnh: {img_path}")
    print(f"Nhãn thực tế: {true_label}")
    print(f"RF dự đoán: {rf_pred} (ĐÚNG)")
    print(f"SVM dự đoán: {svm_pred} (SAI)")

    plt.figure(figsize=(6, 6))
    img = Image.open(img_path)
    plt.imshow(img)
    plt.title(f"True: {true_label}, RF Pred: {rf_pred} (Correct), SVM Pred: {svm_pred} (Incorrect)")
    plt.axis('off')
    plt.show()
else:
    print("Không có trường hợp RF đúng, SVM sai để hiển thị.")
# Out:
# --- RF correct, SVM incorrect ---
# Ảnh: /content/gdrive/MyDrive/afhq_split/test/cat/4964.png
# Nhãn thực tế: cat
# RF dự đoán: cat (ĐÚNG)
# SVM dự đoán: dog (SAI)

# %% [markdown]
# **Reasoning**:
# I need to display example images for the 'SVM correct/RF incorrect' scenario. I will select a random index from `svm_correct_rf_incorrect_indices`, then retrieve the image path, true label, and both model predictions, and finally display this information along with the image.

# %%
print("\n--- SVM correct, RF incorrect ---")
if len(svm_correct_rf_incorrect_indices) > 0:
    idx = random.choice(svm_correct_rf_incorrect_indices)
    img_path = test_paths[idx]
    true_label = y_test[idx]
    rf_pred = y_pred_rf[idx]
    svm_pred = y_pred_svm[idx]

    print(f"Ảnh: {img_path}")
    print(f"Nhãn thực tế: {true_label}")
    print(f"RF dự đoán: {rf_pred} (SAI)")
    print(f"SVM dự đoán: {svm_pred} (ĐÚNG)")

    plt.figure(figsize=(6, 6))
    img = Image.open(img_path)
    plt.imshow(img)
    plt.title(f"True: {true_label}, RF Pred: {rf_pred} (Incorrect), SVM Pred: {svm_pred} (Correct)")
    plt.axis('off')
    plt.show()
else:
    print("Không có trường hợp SVM đúng, RF sai để hiển thị.")
# Out:
# --- SVM correct, RF incorrect ---
# Ảnh: /content/gdrive/MyDrive/afhq_split/test/cat/4633.png
# Nhãn thực tế: cat
# RF dự đoán: dog (SAI)
# SVM dự đoán: cat (ĐÚNG)

# %% [markdown]
# **Reasoning**:
# I need to display example images for the 'both incorrect' scenario. I will select a random index from `both_incorrect_indices`, then retrieve the image path, true label, and both model predictions, and finally display this information along with the image.

# %%
print("\n--- Cả hai mô hình đều dự đoán sai ---")
if len(both_incorrect_indices) > 0:
    idx = random.choice(both_incorrect_indices)
    img_path = test_paths[idx]
    true_label = y_test[idx]
    rf_pred = y_pred_rf[idx]
    svm_pred = y_pred_svm[idx]

    print(f"Ảnh: {img_path}")
    print(f"Nhãn thực tế: {true_label}")
    print(f"RF dự đoán: {rf_pred} (SAI)")
    print(f"SVM dự đoán: {svm_pred} (SAI)")

    plt.figure(figsize=(6, 6))
    img = Image.open(img_path)
    plt.imshow(img)
    plt.title(f"True: {true_label}, RF Pred: {rf_pred} (Incorrect), SVM Pred: {svm_pred} (Incorrect)")
    plt.axis('off')
    plt.show()
else:
    print("Không có trường hợp cả hai mô hình đều sai để hiển thị.")
# Out:
# --- Cả hai mô hình đều dự đoán sai ---
# Ảnh: /content/gdrive/MyDrive/afhq_split/test/wild/4215.png
# Nhãn thực tế: wild
# RF dự đoán: cat (SAI)
# SVM dự đoán: dog (SAI)

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Tóm tắt và phân tích kết quả so sánh giữa hai mô hình, nêu bật điểm mạnh và điểm yếu của từng mô hình dựa trên các trường hợp dự đoán đã được phân loại.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# 1.  **Số lượng ảnh được phân loại đúng bởi cả hai mô hình là bao nhiêu?**
#     Cả hai mô hình đã phân loại đúng 2392 trường hợp.
#
# 2.  **Số lượng ảnh được phân loại sai bởi cả hai mô hình là bao nhiêu?**
#     Cả hai mô hình đã phân loại sai 285 trường hợp.
#
# 3.  **Số lượng ảnh được Random Forest phân loại đúng nhưng SVM phân loại sai là bao nhiêu?**
#     Có 130 trường hợp Random Forest phân loại đúng nhưng SVM phân loại sai.
#
# 4.  **Số lượng ảnh được SVM phân loại đúng nhưng Random Forest phân loại sai là bao nhiêu?**
#     Có 355 trường hợp SVM phân loại đúng nhưng Random Forest phân loại sai.
#
# ### Data Analysis Key Findings
# *   Random Forest và SVM thể hiện hiệu suất tốt khi cả hai cùng dự đoán đúng 2392 trường hợp.
# *   Random Forest vượt trội hơn SVM trong 130 trường hợp, nơi RF dự đoán đúng còn SVM dự đoán sai.
# *   Tuy nhiên, SVM lại thể hiện khả năng mạnh hơn ở 355 trường hợp, nơi SVM dự đoán đúng còn Random Forest dự đoán sai. Điều này cho thấy SVM có thể xử lý tốt hơn một số mẫu dữ liệu cụ thể mà Random Forest gặp khó khăn.
# *   Có 285 trường hợp mà cả hai mô hình đều dự đoán sai, cho thấy đây là những mẫu dữ liệu khó hoặc mơ hồ mà cả hai thuật toán đều không thể giải quyết hiệu quả.
# *   Các ví dụ minh họa cho thấy sự khác biệt trong lỗi dự đoán. Chẳng hạn, trong một trường hợp, Random Forest dự đoán đúng 'cat' trong khi SVM dự đoán sai là 'dog'. Ngược lại, SVM có thể dự đoán đúng 'cat' khi Random Forest dự đoán sai 'dog'. Đặc biệt, có những ảnh 'wild' mà cả hai mô hình đều dự đoán sai ('cat' và 'dog').
#
# ### Insights or Next Steps
# *   Để cải thiện hiệu suất tổng thể, có thể xem xét việc kết hợp hai mô hình (ensemble learning) hoặc nghiên cứu các đặc trưng (features) mà mỗi mô hình xử lý tốt hơn để xây dựng một mô hình mạnh mẽ hơn.
# *   Nghiên cứu sâu hơn 285 trường hợp mà cả hai mô hình đều dự đoán sai để tìm hiểu nguyên nhân gốc rễ. Điều này có thể giúp xác định các loại ảnh khó hoặc các vấn đề về chất lượng dữ liệu, từ đó cải thiện quy trình tiền xử lý hoặc thu thập thêm dữ liệu.
